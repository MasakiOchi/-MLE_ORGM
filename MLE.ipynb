# %%
import MLE_algorithm as go
import graph_tool.all as gt
from MLE_tools import plot_heatmap
import matplotlib.pyplot as plt

# %%
g = gt.collection.data['lesmis']

vertex_sequence_max, a_max, pin_max, pout_max, l_max = go.MLE_ORGM(g, 1, 10, 0.1, 10, 100)

fig, ax = plt.subplots()
plot_heatmap(ax, g, vertex_sequence_max, a_max)
